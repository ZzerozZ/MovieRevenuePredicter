# %%
from chrome_crawler import Chrome_Crawler
from lib import *

# %%
STUDIO = 'https://www.boxofficemojo.com/studio/chart/?studio=%s.htm'

# %%
STUDIO_XPATH = {
    'name': '/html[1]/body[1]/div[1]/div[3]/div[2]/p[1]/b[1]/font[1]',
    'totals': '/html[1]/body[1]/div[1]/div[3]/div[2]/table[3]/tbody[1]/tr[%d]/td[2]/font[1]',
    'averages': '/html[1]/body[1]/div[1]/div[3]/div[2]/table[3]/tbody[1]/tr[%d]/td[2]/font[1]',
    'numbers': '/html[1]/body[1]/div[1]/div[3]/div[2]/center[1]/font[1]/b[1]/font[1]'
    }

# %%
_chrome_option = webdriver.ChromeOptions()
_chrome_option.add_argument("headless")
chrome_option = _chrome_option
driver = webdriver.Chrome(chrome_options=chrome_option)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: use options instead of chrome_options
#   after removing the cwd from sys.path.

# %%
def get_list_studio():
    listPersons = os.listdir('Persons')
    listStudio = []
    
    for person in listPersons:
        # Verify person is .json file
        if (not(person.endswith('.json'))):
            break
            
        # Create link of person
        url = 'Persons\\%s' %person
        # Get person information
        personInfo = json.load(open(url, 'r'))
        # Get list movies from person
        movies = personInfo['movies']
        for movie in movies:
            listStudio.append(movie['studio']) 
        

    # Remove duplicated values
    studios = np.unique(listStudio)
    return studios

# %%
studios = get_list_studio()
studios = np.delete(studios,0)
studios
# Out:
# array(['3dentertainment', '7thart', 'a24', 'abramorama', 'academyent',
#        'adoptfilms', 'afterdarkfilms', 'aip', 'alchemy', 'alliance',
#        'alliedartists', 'almi', 'alohareleasing', 'amazon', 'ambassador',
#        'ambi', 'americanfilm', 'amplify', 'anchorbayentertainment',
#        'andora', 'angelika', 'annapurna', 'apparition', 'appliedart',
#        'arcent', 'arclightfilms', 'area23a', 'areans',
#        'arongovilproductions', 'arrival', 'arrow', 'arrowfilms',
#        'artisan', 'artisticlicense', 'ascendantpictures',
#        'associatedfilm', 'atlantic', 'atlas', 'atopictures', 'attitude',
#        'avco', 'avenue', 'aviron', 'balcony', 'banner', 'bauermartinez',
#        'bbcworldwide', 'bdfox', 'beechhill', 'bevpictures', 'bhtilt',
#        'billplympton', 'bleeckerstreet', 'bluesteel', 'borotoro',
#        'bowandarrow', 'brainstormanddoublehope', 'brainstormmedia',
#        'broadgreen', 'buenavista', 'cannon', 'capitolentertainment',
#        'castlehill', 'cbsfilms', 'cfireleasing', 'cfp', 'christalfilms',
#        'cinecom', 'cinedigmentertainment', 'cinelou', 'cinema5',
#        'cineplexodeon', 'cinerama', 'cinetel', 'circle',
#        'citylightsmedia', 'cjentertainment', 'clarius', 'cloudten', 'cls',
#        'codeblackentertainment', 'cohenmedia', 'columbia', 'comworld',
#        'concorde', 'convexgroup', 'corinthfilmsinc', 'corsair', 'cowboy',
#        'crown', 'cyanpictures', 'dada', 'ddm', 'deg', 'dej',
#        'destination', 'dimension', 'drafthousefilms', 'dreamworks',
#        'e1entertainment', 'eammonfilms', 'echobridge', 'electric',
#        'elevenarts', 'embassy', 'emerging', 'empirepictures',
#        'entertainmentone', 'entertainmentstudios', 'europacorp',
#        'europeanclassics', 'excel', 'exclusivemedia', 'fabricationfilms',
#        'fathom', 'filmarcade', 'filmdistrict', 'filmfoundry',
#        'filmmovement', 'filmrise', 'filmways', 'fineline',
#        'firstindependentpictures', 'firstlook', 'firstrun', 'foak',
#        'focus', 'focusworld', 'fox', 'foxatomic', 'foxintlclassics',
#        'foxsearchlight', 'frontstreet', 'fs', 'funacademy', 'gkids',
#        'globalroad', 'goldcircle', 'gooddeed', 'goodmachine', 'gramercy',
#        'gravitas', 'greatpoint', 'greycat', 'gunpowderandsky', 'gvn',
#        'hannoverhouse', 'heartland', 'hemdale', 'hightop', 'horne',
#        'icarus', 'idp', 'ifc', 'imageentertainment', 'imax',
#        'independent', 'indican', 'indomina', 'innovation', 'interstar',
#        'intlfilmcircuit', 'invincible', 'irsmedia', 'island',
#        'islandalive', 'janusfilms', 'jensenfarley', 'johnaaron',
#        'jourdefete', 'kennviselman', 'ketchup', 'keystone',
#        'kindredmediagroup', 'kingroad', 'kino', 'kinolorber', 'kitparker',
#        'lanternlane', 'lddistribution', 'legacy', 'leisuretime',
#        'liberationentertainment', 'libertystudios', 'lions_gate',
#        'lionsgate', 'lionsgatepremiere', 'lionsgatesummit', 'littlevilla',
#        'lorimar', 'lot47', 'macgillivrayfreeman', 'macreleasing',
#        'magnolia', 'mainstreetfilms', 'mangustaproductions', 'manhattan',
#        'manray', 'mayaentertainment', 'mceg', 'mdp', 'menemsha', 'mgm',
#        'mgmweinstein', 'millenniumentertainment', 'millenniumfilms',
#        'miramax', 'mirrld', 'mitropoulosfilms', 'momentumpictures',
#        'montereymediainc', 'moonstone', 'morningstar', 'moviestore',
#        'mpft', 'mpimediagroup', 'musicboxfilms', 'myriadpictures',
#        'nascent', 'nationalgeneral', 'nationalgeographiccinema',
#        'neoclassicsfilms', 'neon', 'netflix', 'neverland', 'newcentury',
#        'newline', 'newmarket', 'newworld', 'newyorker', 'northerarts',
#        'nwave', 'october', 'odeon', 'openroads', 'orchard', 'orion',
#        'orionclassics', 'oscilloscopepictures', 'overturefilms',
#        'pacific', 'paladin', 'palisades', 'palm', 'panorama', 'pantelion',
#        'paramount', 'paramountclassics', 'paramountinsruge',
#        'paramountvantage', 'pardw', 'participant', 'pda',
#        'peacearchentertainment', 'peacefilm', 'peninsula', 'phaedra',
#        'phase4', 'picturehouse', 'picturehouse2', 'pmkbncfilms',
#        'polygram', 'priorityfilms', 'pureflix', 'radiustwc',
#        'rafindustries', 'rainbow', 'rainforest', 'rcr', 'redflag',
#        'redwoodpalmspictures', 'reeldivaconsultants', 'reelsource',
#        'regent', 'relativity', 'revolutionstudios', 'rko', 'rlj',
#        'roadshow', 'roadsideattractions', 'rockymountainpictures',
#        'roguepictures', 'rollingthunder', 'romar', 'roxie', 'rs',
#        'sabanfilms', 'samuelgoldwyn', 'satori', 'savoy', 'screengems',
#        'screenmedia', 'senartfilms', 'senatordistribution', 'shadow',
#        'shapiroglickenhaus', 'silvernitrate', 'singulardtv', 'skouras',
#        'slowhand', 'smallplanet', 'smodcast', 'sony', 'sonyclassics',
#        'southgateentertainment', 'spacey', 'sphe', 'spitnglue',
#        'starzmedia', 'steelyardpictures', 'strand', 'stratosphere', 'stx',
#        'summitentertainment', 'sundance', 'swipe', 'tartan', 'taurus',
#        'tenfurlongs', 'thebiggerpicture', 'thinkfilm',
#        'thirdrailreleasing', 'threekingsproductions', 'tla', 'transworld',
#        'tribecafilm', 'trimark', 'tristar', 'triton', 'triumph', 'troma',
#        'trulyindie', 'tsg', 'twomoon', 'ua', 'unapix', 'universal',
#        'unknown', 'urbanworld', 'usa', 'variancefilms', 'veracity',
#        'vertical', 'vestron', 'visioentertainment', 'vision', 'vitagraph',
#        'vivendientertainment', 'warnerbros', 'wb-newline', 'wdimension',
#        'weinsteincompany', 'wellgo', 'wellspring', 'wildcatreleasing',
#        'winewomenandsong', 'wip', 'wolfereleasing', 'worldartists',
#        'wreckinhill', 'xenonpictures', 'xlratormedia', 'yarifilmgroup'],
#       dtype='<U24')

# %%
def create_url(studio):
    return STUDIO % studio

# %%
def get_studio_info(url):
    driver.get(url)
    
    id = url.split('studio=')[1][:-4]
    
    
    try:
        name = driver.find_element_by_xpath(STUDIO_XPATH['name']).text
        numbers = driver.find_element_by_xpath(STUDIO_XPATH['numbers']).text[3:]
        numbers = int(numbers)
        totals = driver.find_element_by_xpath(STUDIO_XPATH['totals'] %(numbers+3)).text.split('$')[1]
        averages = driver.find_element_by_xpath(STUDIO_XPATH['averages'] %(numbers+4)).text.split('$')[1]
#     totals = ''
#     averages = ''
    except:
        numbers = ''
        totals = ''
        averages = ''
        
    studio = {
        'id':id,
        'name':name,
        'totals':totals,
        'averages':averages
    }
    
    return studio

# %%
_round = 0
chrome_crawler = Chrome_Crawler()

while _round < len(studios):
    studioInfo = get_studio_info(create_url(studios[_round]))
    id = studioInfo['id']
    if (studioInfo['totals'] == '' or studioInfo['averages'] == ''):
        print('exception: %s' % id)
        with open('StudioExceptions.txt', 'a+') as f_except:
            f_except.write(id + '\n')
    else:
        try:
            with open('Studios/%s.json' % id, 'w') as fp:
                json.dump(studioInfo, fp)

            time.sleep(np.random.randint(1,4)/4)

            # Reset driver:
            if _round % 10 == 0:
                print ("Crawling studio...\t%d/%d\n"%(_round, len(studios)))
                chrome_crawler.restart_crawler(delay_time=15)
        except:
            print('exception: %s' % id)
            with open('StudioExceptions.txt', 'a+') as f_except:
                f_except.write(id + '\n')
            
    _round += 1
# Out:
# Crawling studio...	0/363
#
# Crawling studio...	10/363
#
# exception: ambassador
# exception: americanfilm
# Crawling studio...	20/363
#
# exception: appliedart
# exception: arclightfilms
# exception: arongovilproductions
# Crawling studio...	30/363
#
# exception: ascendantpictures
# Crawling studio...	40/363
#
# exception: beechhill
# Crawling studio...	50/363
#
# Crawling studio...	60/363
#
# exception: cinema5
# exception: cinerama
# Crawling studio...	80/363
#
# exception: convexgroup
# Crawling studio...	90/363
#
# Crawling studio...	100/363
#
# exception: europeanclassics
# Crawling studio...	120/363
#
# exception: foxintlclassics
# exception: frontstreet
# Crawling studio...	140/363
#
# Crawling studio...	150/363
#
# Crawling studio...	160/363
#
# exception: invincible
# Crawling studio...	170/363
#
# Crawling studio...	180/363
#
# Crawling studio...	190/363
#
# exception: mdp
# Crawling studio...	210/363
#
# exception: nascent
# Crawling studio...	220/363
#
# exception: netflix
# Crawling studio...	230/363
#
# Crawling studio...	240/363
#
# Crawling studio...	250/363
#
# Crawling studio...	260/363
#
# exception: rafindustries
# Crawling studio...	270/363
#
# exception: roadshow
# Crawling studio...	280/363
#
# exception: satori
# Crawling studio...	290/363
#
# Crawling studio...	300/363
#
# Crawling studio...	310/363
#
# exception: swipe
# Crawling studio...	320/363
#
# exception: threekingsproductions
# Crawling studio...	330/363
#
# Crawling studio...	340/363
#
# Crawling studio...	350/363
#
# Crawling studio...	360/363
