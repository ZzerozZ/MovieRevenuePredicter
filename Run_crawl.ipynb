# %%
from genre import *
from movie import *
from person import *
from lib import *
from xpath import *

# %%
import json
from chrome_crawler import Chrome_Crawler
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
movies = load_obj('/home/nghia/Desktop/Lab/Movie/obj/all_movie')
movies = [movies[i] for i in range(len(movies)) if i not in [3, 160]]
movie_list = []
studio_list = []
for i in range(len(movies)):
    movie_list += movies[i][1]
    studio_list += movies[i][-1]

# %%
df = pd.DataFrame([movie_list, studio_list]).T
df.columns = ['movie', 'studio']
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#            movie      studio
# 0      starwars7  buenavista
# 1         avatar         fox
# 2    marvel2017b  buenavista
# 3     marvel0518  buenavista
# 4  jurassicpark4   universal

# %%
save_obj(df, 'obj/df_movie_studio')
# Out:
# 1

# %%
movie_crawler = Movie_Crawler()

_round = 1
for movie in df.movie.values:
    try:
        movie_info = movie_crawler.get_movie_info(movie, num_actor=5)
        with open('Movies/{movie}.json', 'w') as fp:
            json.dump(movie_info, fp)

        time.sleep(np.random.randint(1,4)/4)

        # Reset driver:
        if _round % 50 == 0:
            print ("Crawling movie...\t%d/%d\n"%(_round, df.movie.shape[0]))
            movie_crawler.restart_crawler(delay_time=15)
        _round += 1
    except:
        with open('exceptions.txt', 'a+') as f_except:
            f_except.write(movie + '\n')
# Out:
# Crawling movie...	50/10668
#
# Crawling movie...	100/10668
#
# Crawling movie...	150/10668
#
# Crawling movie...	200/10668
#
# Crawling movie...	250/10668
#
# Crawling movie...	300/10668
#
# Crawling movie...	350/10668
#
# Crawling movie...	400/10668
#
# Crawling movie...	450/10668
#
# Crawling movie...	500/10668
#
# Crawling movie...	550/10668
#
# Crawling movie...	600/10668
#
# Crawling movie...	650/10668
#
# Crawling movie...	700/10668
#
# Crawling movie...	750/10668
#
# Crawling movie...	800/10668
#
# Crawling movie...	850/10668
#
# Crawling movie...	900/10668
#
# Crawling movie...	950/10668
#
# Crawling movie...	1000/10668
#
# Crawling movie...	1050/10668
#
# Crawling movie...	1100/10668
#
# Crawling movie...	1150/10668
#
# Crawling movie...	1200/10668
#
# Crawling movie...	1250/10668
#
# Crawling movie...	1300/10668
#
# Crawling movie...	1350/10668
#
# Crawling movie...	1400/10668
#
# Crawling movie...	1450/10668
#
# Crawling movie...	1500/10668
#
# Crawling movie...	1550/10668
#
# Crawling movie...	1600/10668
#
# Crawling movie...	1650/10668
#
# Crawling movie...	1700/10668
#
# Crawling movie...	1750/10668
#
# Crawling movie...	1800/10668
#
# Crawling movie...	1850/10668
#
# Crawling movie...	1900/10668
#
# Crawling movie...	1950/10668
#
# Crawling movie...	2000/10668
#
# Crawling movie...	2050/10668
#
# Crawling movie...	2100/10668
#
# Crawling movie...	2150/10668
#
# Crawling movie...	2200/10668
#
# Crawling movie...	2250/10668
#
# Crawling movie...	2300/10668
#
# Crawling movie...	2350/10668
#
# Crawling movie...	2400/10668
#
# Crawling movie...	2450/10668
#
# Crawling movie...	2500/10668
#
# Crawling movie...	2550/10668
#
# Crawling movie...	2600/10668
#
# Crawling movie...	2650/10668
#
# Crawling movie...	2700/10668
#
# Crawling movie...	2750/10668
#
# Crawling movie...	2800/10668
#
# Crawling movie...	2850/10668
#
# Crawling movie...	2900/10668
#
# Crawling movie...	2950/10668
#
# Crawling movie...	3000/10668
#
# Crawling movie...	3050/10668
#
# Crawling movie...	3100/10668
#
# Crawling movie...	3150/10668
#
# Crawling movie...	3200/10668
#
# Crawling movie...	3250/10668
#
# Crawling movie...	3300/10668
#
# Crawling movie...	3350/10668
#
# Crawling movie...	3400/10668
#
# Crawling movie...	3450/10668
#
# Crawling movie...	3500/10668
#
# Crawling movie...	3550/10668
#
# Crawling movie...	3600/10668
#
# Crawling movie...	3650/10668
#
# Crawling movie...	3700/10668
#
# Crawling movie...	3750/10668
#
# Crawling movie...	3800/10668
#
# Crawling movie...	3850/10668
#
# Crawling movie...	3900/10668
#
# Crawling movie...	3950/10668
#
# Crawling movie...	4000/10668
#
# Crawling movie...	4050/10668
#
# Crawling movie...	4100/10668
#
# Crawling movie...	4150/10668
#
# Crawling movie...	4200/10668
#
# Crawling movie...	4250/10668
#
# Crawling movie...	4300/10668
#
# Crawling movie...	4350/10668
#
# Crawling movie...	4400/10668
#
# Crawling movie...	4450/10668
#
# Crawling movie...	4500/10668
#
# Crawling movie...	4550/10668
#
# Crawling movie...	4600/10668
#
# Crawling movie...	4650/10668
#
# Crawling movie...	4700/10668
#
# Crawling movie...	4750/10668
#
# Crawling movie...	4800/10668
#
# Crawling movie...	4850/10668
#
# Crawling movie...	4900/10668
#
# Crawling movie...	4950/10668
#
# Crawling movie...	5000/10668
#
# Crawling movie...	5050/10668
#
# Crawling movie...	5100/10668
#
# Crawling movie...	5150/10668
#
# Crawling movie...	5200/10668
#
# Crawling movie...	5250/10668
#
# Crawling movie...	5300/10668
#
# Crawling movie...	5350/10668
#
# Crawling movie...	5400/10668
#
# Crawling movie...	5450/10668
#
# Crawling movie...	5500/10668
#
# Crawling movie...	5550/10668
#
# Crawling movie...	5600/10668
#
# Crawling movie...	5650/10668
#
# Crawling movie...	5700/10668
#
# Crawling movie...	5750/10668
#
# Crawling movie...	5800/10668
#
# Crawling movie...	5850/10668
#
# Crawling movie...	5900/10668
#
# Crawling movie...	5950/10668
#
# Crawling movie...	6000/10668
#
# Crawling movie...	6050/10668
#
# Crawling movie...	6100/10668
#
# Crawling movie...	6150/10668
#
# Crawling movie...	6200/10668
#
# Crawling movie...	6250/10668
#
# Crawling movie...	6300/10668
#
# Crawling movie...	6350/10668
#
# Crawling movie...	6400/10668
#
# Crawling movie...	6450/10668
#
# Crawling movie...	6500/10668
#
# Crawling movie...	6550/10668
#
# Crawling movie...	6600/10668
#
# Crawling movie...	6650/10668
#
# Crawling movie...	6700/10668
#
# Crawling movie...	6750/10668
#
# Crawling movie...	6800/10668
#
# Crawling movie...	6850/10668
#
# Crawling movie...	6900/10668
#
# Crawling movie...	6950/10668
#
# Crawling movie...	7000/10668
#
# Crawling movie...	7050/10668
#
# Crawling movie...	7100/10668
#
# Crawling movie...	7150/10668
#
# Crawling movie...	7200/10668
#
# Crawling movie...	7250/10668
#
# Crawling movie...	7300/10668
#
# Crawling movie...	7350/10668
#
# Crawling movie...	7400/10668
#
# Crawling movie...	7450/10668
#
# Crawling movie...	7500/10668
#
# Crawling movie...	7550/10668
#
# Crawling movie...	7600/10668
#
# Crawling movie...	7650/10668
#
# Crawling movie...	7700/10668
#
# Crawling movie...	7750/10668
#
# Crawling movie...	7800/10668
#
# Crawling movie...	7850/10668
#
# Crawling movie...	7900/10668
#
# Crawling movie...	7950/10668
#
# Crawling movie...	8000/10668
#
# Crawling movie...	8050/10668
#
# Crawling movie...	8100/10668
#
# Crawling movie...	8150/10668
#
# Crawling movie...	8200/10668
#
# Crawling movie...	8250/10668
#
# Crawling movie...	8300/10668
#
# Crawling movie...	8350/10668
#
# Crawling movie...	8400/10668
#
# Crawling movie...	8450/10668
#
# Crawling movie...	8500/10668
#
# Crawling movie...	8550/10668
#
# Crawling movie...	8600/10668
#
# Crawling movie...	8650/10668
#
# Crawling movie...	8700/10668
#
# Crawling movie...	8750/10668
#
# Crawling movie...	8800/10668
#
# Crawling movie...	8850/10668
#
# Crawling movie...	8900/10668
#
# Crawling movie...	8950/10668
#
# Crawling movie...	9000/10668
#
# Crawling movie...	9050/10668
#
# Crawling movie...	9100/10668
#
# Crawling movie...	9150/10668
#
# Crawling movie...	9200/10668
#
# Crawling movie...	9250/10668
#
# Crawling movie...	9300/10668
#
# Crawling movie...	9350/10668
#
# Crawling movie...	9400/10668
#
# Crawling movie...	9450/10668
#
# Crawling movie...	9500/10668
#
# Crawling movie...	9550/10668
#
# Crawling movie...	9600/10668
#
# Crawling movie...	9650/10668
#
# Crawling movie...	9700/10668
#
# Crawling movie...	9750/10668
#
# Crawling movie...	9800/10668
#
# Crawling movie...	9850/10668
#
# Crawling movie...	9900/10668
#
# Crawling movie...	9950/10668
#
# Crawling movie...	10000/10668
#
# Crawling movie...	10050/10668
#
# Crawling movie...	10100/10668
#
# Crawling movie...	10150/10668
#
# Crawling movie...	10200/10668
#
# Crawling movie...	10250/10668
#
# Crawling movie...	10300/10668
#
# Crawling movie...	10350/10668
#
# Crawling movie...	10400/10668
#
# Crawling movie...	10450/10668
#
# Crawling movie...	10500/10668
#
# Crawling movie...	10550/10668
#
# Crawling movie...	10600/10668
#
# Crawling movie...	10650/10668
